# %% [markdown]
# Задача 1

# %% [markdown]
# О непрерывной равномерно распределенной случайной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %% [markdown]
# Математическое ожидание и дисперсия равномерного распределения:
#
# $$M(X) = \dfrac{a + b}{2}, \text{ } D(X) = \dfrac{(b - a)^2}{12}.$$

# %% [markdown]
# по условиям имеем a=0.5 и D(X)=0.2.
# подставляем в формулы:

# %% [markdown]
# $$\text{ } D(X) = \dfrac{(b - 0.5)^2}{12}=0.2.$$

# %% [markdown]
# Получаем b=0,5+-sqrt(2.4). так как по условиям ищем правую границу и b Должно быть больше а, то оставляем корень с положительным знаком.
# b=0.5+sqrt(2.4)

# %% [markdown]
# $$M(X) = \dfrac{a + b}{2}= \dfrac{0.5+0.5+sqrt(2.4)}{2}=0.5+sqrt(0.6).$$

# %% [markdown]
# Задача 2

# %% [markdown]
# На сколько сигм (средних квадратических отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 и D(X) = 25?

# %% [markdown]
# Сигма равна квадратному корню из дисперсии.
# в нашем случае сигма=5.
#
# Имеем,
#
# (190-178)/5=2,4
# А значит рост человека, равный 190 см, попадает в диапазон от двух до трех сигм(в нем находятся 2,1 % всех значений)

# %% [markdown]
# Задача 3

# %% [markdown]
# Рост взрослого населения города X имеет нормальное распределение, причем, средний рост равен 174 см, а среднее квадратическое отклонение равно 8 см. Без использования сторонних библиотек (numpy, scipy, pandas и пр.) посчитайте, какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# 1. больше 182 см?
# 2. больше 190 см?
# 3. от 166 см до 190 см?
# 4. от 166 см до 182 см?
# 5. от 158 см до 190 см?
# 6. не выше 150 см или не ниже 190 см?
# 7. не выше 150 см или не ниже 198 см?
# 8. ниже 166 см?

# %% [markdown]
# 1. 182-174=8 = 1 сигма
# рост больше 182 см с вероятностью 15,9 %
#
# 2 190-174=16 = 2 сигма
# рост больше 190 см с вероятностью 2,3 %

# %% [markdown]
# 3 174-166=8 = 1 сигма
#
# диапазон -сигма:+2 сигма
#
# вероятность что величина попадет в диапазон 166-190: 81,8 %
#
# 4 диапазон - сигма:+сигма
#
# вероятность попададания величины в данный диапазон: 68,2 %

# %% [markdown]
# 5. диапазон -2 сигма: + 2 сигма
#
# вероятность попадания в данный диапазон: 95,4 %
#
# 6. диапазон -3 сигма: + 2 сигма
#
# вероятность не попадания в диапазон: 2,5%
#
# 7. диапазон - 3 сигма: +3 сигма
#
# вероятность не попадания в диапазон 0,4 %
#
# 8. вероятность что рост ниже 166 см составляет 15,9 %
